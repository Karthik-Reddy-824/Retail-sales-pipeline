# %%
import sqlite3
import pandas as pd

conn = sqlite3.connect('../db/sales.db')

# %%
orders = pd.read_sql("SELECT * FROM orders", conn)
orders.head()
# Out:
#          Order ID           Order Date            Ship Date Customer ID  \
# 0  CA-2016-152156  2016-11-08 00:00:00  2016-11-11 00:00:00    CG-12520
# 1  CA-2016-152156  2016-11-08 00:00:00  2016-11-11 00:00:00    CG-12520
# 2  CA-2016-138688  2016-06-12 00:00:00  2016-06-16 00:00:00    DV-13045
# 3  US-2015-108966  2015-10-11 00:00:00  2015-10-18 00:00:00    SO-20335
# 4  US-2015-108966  2015-10-11 00:00:00  2015-10-18 00:00:00    SO-20335
#
#         Product ID Region   Revenue
# 0  FUR-BO-10001798  South  261.9600
# 1  FUR-CH-10000454  South  731.9400
# 2  OFF-LA-10000240   West   14.6200
# 3  FUR-TA-10000577  South  957.5775
# 4  OFF-ST-10000760  South   22.3680

# %%
# Total Revenue
orders['Revenue'].sum()
# Out:
# np.float64(1988.4655)

# %%
orders.groupby('Region')['Revenue'].sum()
# Out:
# Region
# South    1973.8455
# West       14.6200
# Name: Revenue, dtype: float64

# %%
orders['Order Date'] = pd.to_datetime(orders['Order Date'])

orders.groupby(orders['Order Date'].dt.to_period('M'))['Revenue'].sum()
# Out:
# Order Date
# 2015-10    979.9455
# 2016-06     14.6200
# 2016-11    993.9000
# Freq: M, Name: Revenue, dtype: float64

# %%
orders.groupby('Product ID')['Revenue'].sum().sort_values(ascending=False).head(5)
# Out:
# Product ID
# FUR-TA-10000577    957.5775
# FUR-CH-10000454    731.9400
# FUR-BO-10001798    261.9600
# OFF-ST-10000760     22.3680
# OFF-LA-10000240     14.6200
# Name: Revenue, dtype: float64

# %%
import matplotlib.pyplot as plt

orders.groupby('Region')['Revenue'].sum().plot(kind='bar')
plt.title("Revenue by Region")
plt.show()

# %% [markdown]
# South region generates highest revenue
# Sales peak during certain months
# Few products dominate revenue
